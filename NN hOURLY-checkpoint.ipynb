# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPRegressor


daily_stat = pd.read_csv('hourly_stat.csv').dropna()
daily_stat

df=daily_stat.dropna()

features = df[['SH_temp_mean', 'SH_hum_mean', 'DWH_temp_mean', 'DWH_hum_mean']].dropna()
target = df['Gas_mean'].dropna()

# Normalize features
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Split data
X_train, X_test, y_train, y_test, date_train, date_test = train_test_split(features_scaled, target, daily_stat['date'], test_size=0.2, random_state=42)




# Build neural network model
model = MLPRegressor(hidden_layer_sizes=(16, 8), activation='relu', solver='adam', max_iter=500, random_state=42)

# Train model
model.fit(X_train, y_train)

# Evaluate model
loss = model.score(X_test, y_test)
print(f'Test R^2 Score: {loss}')

# Plotting training loss values
plt.plot(model.loss_curve_)
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.show()


df.dtypes

# Predict gas consumption on the test set
predictions = model.predict(X_test)



# Compare actual vs predicted SH and DWH gas consumption
plt.figure(figsize=(14, 7))

plt.subplot(1, 2, 1)
plt.scatter(range(len(y_test)), y_test, label='Actual Total Gas Consumption')
plt.scatter(range(len(y_test)), predictions, label='Predicted Total Gas Consumption', alpha=0.7)
plt.title('Total Gas Consumption')
plt.xlabel('Sample')
plt.ylabel('Gas Consumption')
plt.legend()




# Plot actual vs predicted gas consumption over time
plt.figure(figsize=(14, 7))
plt.plot(date_test, y_test, label='Actual Gas Consumption', marker='o')
plt.plot(date_test, predictions, label='Predicted Gas Consumption', marker='x', linestyle='--')
plt.xlabel('Date')
plt.ylabel('Gas Consumption')
plt.title('Actual vs Predicted Gas Consumption')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()



from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_percentage_error, r2_score

# Calculate evaluation metrics
mae_1 = mean_absolute_error(y_test, predictions)
mse_1 = mean_squared_error(y_test, predictions)
r2_1 = r2_score(y_test, predictions)
mape_1 = mean_absolute_percentage_error(y_test, predictions)

print(f'Mean Absolute Error (MAE): {mae_1}')
print(f'Mean Squared Error (MSE): {mse_1}')
print(f'R-squared (R²): {r2_1}')
print(f'Mean Absolute Percentage Error (MAPE): {mape_1}%')
# Out:
# Test R^2 Score: 0.1640193136631899
# Mean Absolute Error (MAE): 0.03280210065685431
# Mean Squared Error (MSE): 0.0016969751724078593
# R-squared (R²): 0.1640193136631899
# Mean Absolute Percentage Error (MAPE): 1.6480731301872578%

# %%
import math
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score

# Calculate evaluation metrics
mae_NN  = mean_absolute_error(y_test, predictions)
mse_NN = mean_squared_error(y_test, predictions)
rmse_NN= math.sqrt(mse_NN)
r2_NN = r2_score(y_test, predictions)
n = len(y_test)
p = X_test.shape[1]
adjusted_r2_NN = 1 - (1 - r2_NN) * (n - 1) / (n - p - 1)
mape_NN = mean_absolute_percentage_error(y_test, predictions)

print(f'Mean Squared Error (MSE): {mae_NN }')
print(f'Root Mean Squared Error (RMSE): {mse_NN }')
print(f'R-squared (R²): {r2_NN }')
print(f'Adjusted R-squared (R²): {adjusted_r2_NN }')

print(f'Mean Absolute Error (MAE): {mae_NN }')
print(f'Mean Absolute Percentage Error (MAPE): {mape_NN }%')
# Out:
# Mean Squared Error (MSE): 0.03280210065685431
# Root Mean Squared Error (RMSE): 0.0016969751724078593
# R-squared (R²): 0.1640193136631899
# Adjusted R-squared (R²): 0.16200247244162946
# Mean Absolute Error (MAE): 0.03280210065685431
# Mean Absolute Percentage Error (MAPE): 1.6480731301872578%

# %% [markdown]
# # SH

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPRegressor


daily_stat = pd.read_csv('hourly_stat.csv').dropna()
daily_stat

df=daily_stat.dropna()

features = df[['SH_temp_mean', 'SH_hum_mean']].dropna()
target = df['Gas_mean'].dropna()

# Normalize features
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Split data
X_train, X_test, y_train, y_test, date_train, date_test = train_test_split(features_scaled, target, daily_stat['date'], test_size=0.2, random_state=42)




# Build neural network model
model = MLPRegressor(hidden_layer_sizes=(16, 8), activation='relu', solver='adam', max_iter=500, random_state=42)

# Train model
model.fit(X_train, y_train)

# Evaluate model
loss = model.score(X_test, y_test)
print(f'Test R^2 Score: {loss}')

# Plotting training loss values
plt.plot(model.loss_curve_)
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.show()


df.dtypes

# Predict gas consumption on the test set
predictions = model.predict(X_test)



# Compare actual vs predicted SH and DWH gas consumption
plt.figure(figsize=(14, 7))

plt.subplot(1, 2, 1)
plt.scatter(range(len(y_test)), y_test, label='Actual Total Gas Consumption')
plt.scatter(range(len(y_test)), predictions, label='Predicted Total Gas Consumption', alpha=0.7)
plt.title('Total Gas Consumption')
plt.xlabel('Sample')
plt.ylabel('Gas Consumption')
plt.legend()




# Plot actual vs predicted gas consumption over time
plt.figure(figsize=(14, 7))
plt.plot(date_test, y_test, label='Actual Gas Consumption', marker='o')
plt.plot(date_test, predictions, label='Predicted Gas Consumption', marker='x', linestyle='--')
plt.xlabel('Date')
plt.ylabel('Gas Consumption')
plt.title('Actual vs Predicted Gas Consumption')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()



from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_percentage_error, r2_score

# Calculate evaluation metrics
mae_1 = mean_absolute_error(y_test, predictions)
mse_1 = mean_squared_error(y_test, predictions)
r2_1 = r2_score(y_test, predictions)
mape_1 = mean_absolute_percentage_error(y_test, predictions)

print(f'Mean Absolute Error (MAE): {mae_1}')
print(f'Mean Squared Error (MSE): {mse_1}')
print(f'R-squared (R²): {r2_1}')
print(f'Mean Absolute Percentage Error (MAPE): {mape_1}%')
# Out:
# Test R^2 Score: 0.25895826391594534
# Mean Absolute Error (MAE): 0.02922100711430931
# Mean Squared Error (MSE): 0.0015042565556903419
# R-squared (R²): 0.25895826391594534
# Mean Absolute Percentage Error (MAPE): 1.5312544697516945%

# %%
import math
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score

# Calculate evaluation metrics
mae_NN_SH = mean_absolute_error(y_test, predictions)
mse_NN_SH = mean_squared_error(y_test, predictions)
rmse_NN_SH= math.sqrt(mse_NN_SH)
r2_NN_SH = r2_score(y_test, predictions)
n = len(y_test)
p = X_test.shape[1]
adjusted_r2_NN_SH = 1 - (1 - r2_NN_SH) * (n - 1) / (n - p - 1)
mape_NN_SH = mean_absolute_percentage_error(y_test, predictions)

print(f'Mean Squared Error (MSE): {mae_NN_SH }')
print(f'Root Mean Squared Error (RMSE): {mse_NN_SH }')
print(f'R-squared (R²): {r2_NN_SH }')
print(f'Adjusted R-squared (R²): {adjusted_r2_NN_SH }')

print(f'Mean Absolute Error (MAE): {mae_NN_SH }')
print(f'Mean Absolute Percentage Error (MAPE): {mape_NN_SH }%')
# Out:
# Mean Squared Error (MSE): 0.02922100711430931
# Root Mean Squared Error (RMSE): 0.0015042565556903419
# R-squared (R²): 0.25895826391594534
# Adjusted R-squared (R²): 0.25806544254716934
# Mean Absolute Error (MAE): 0.02922100711430931
# Mean Absolute Percentage Error (MAPE): 1.5312544697516945%

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPRegressor


daily_stat = pd.read_csv('hourly_stat.csv').dropna()
daily_stat

df=daily_stat.dropna()

features = df[[ 'DWH_temp_mean', 'DWH_hum_mean']].dropna()
target = df['Gas_mean'].dropna()

# Normalize features
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Split data
X_train, X_test, y_train, y_test, date_train, date_test = train_test_split(features_scaled, target, daily_stat['date'], test_size=0.2, random_state=42)




# Build neural network model
model = MLPRegressor(hidden_layer_sizes=(16, 8), activation='relu', solver='adam', max_iter=500, random_state=42)

# Train model
model.fit(X_train, y_train)

# Evaluate model
loss = model.score(X_test, y_test)
print(f'Test R^2 Score: {loss}')

# Plotting training loss values
plt.plot(model.loss_curve_)
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.show()


df.dtypes

# Predict gas consumption on the test set
predictions = model.predict(X_test)



# Compare actual vs predicted SH and DWH gas consumption
plt.figure(figsize=(14, 7))

plt.subplot(1, 2, 1)
plt.scatter(range(len(y_test)), y_test, label='Actual Total Gas Consumption')
plt.scatter(range(len(y_test)), predictions, label='Predicted Total Gas Consumption', alpha=0.7)
plt.title('Total Gas Consumption')
plt.xlabel('Sample')
plt.ylabel('Gas Consumption')
plt.legend()




# Plot actual vs predicted gas consumption over time
plt.figure(figsize=(14, 7))
plt.plot(date_test, y_test, label='Actual Gas Consumption', marker='o')
plt.plot(date_test, predictions, label='Predicted Gas Consumption', marker='x', linestyle='--')
plt.xlabel('Date')
plt.ylabel('Gas Consumption')
plt.title('Actual vs Predicted Gas Consumption')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()



from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_percentage_error, r2_score

# Calculate evaluation metrics
mae_1 = mean_absolute_error(y_test, predictions)
mse_1 = mean_squared_error(y_test, predictions)
r2_1 = r2_score(y_test, predictions)
mape_1 = mean_absolute_percentage_error(y_test, predictions)

print(f'Mean Absolute Error (MAE): {mae_1}')
print(f'Mean Squared Error (MSE): {mse_1}')
print(f'R-squared (R²): {r2_1}')
print(f'Mean Absolute Percentage Error (MAPE): {mape_1}%')
# Out:
# Test R^2 Score: 0.06324106616287706
# Mean Absolute Error (MAE): 0.03454278247919436
# Mean Squared Error (MSE): 0.0019015471041784258
# R-squared (R²): 0.06324106616287706
# Mean Absolute Percentage Error (MAPE): 1.990898616488345%

# %%
import math
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score

# Calculate evaluation metrics
mae_NN_DWH  = mean_absolute_error(y_test, predictions)
mse_NN_DWH = mean_squared_error(y_test, predictions)
rmse_NN_DWH= math.sqrt(mse_NN_DWH)
r2_NN_DWH = r2_score(y_test, predictions)
n = len(y_test)
p = X_test.shape[1]
adjusted_r2_NN_DWH = 1 - (1 - r2_NN_DWH) * (n - 1) / (n - p - 1)
mape_NN_DWH = mean_absolute_percentage_error(y_test, predictions)

print(f'Mean Squared Error (MSE): {mae_NN_DWH }')
print(f'Root Mean Squared Error (RMSE): {mse_NN_DWH }')
print(f'R-squared (R²): {r2_NN_DWH }')
print(f'Adjusted R-squared (R²): {adjusted_r2_NN_DWH }')

print(f'Mean Absolute Error (MAE): {mae_NN_DWH }')
print(f'Mean Absolute Percentage Error (MAPE): {mape_NN_DWH }%')
# Out:
# Mean Squared Error (MSE): 0.03454278247919436
# Root Mean Squared Error (RMSE): 0.0019015471041784258
# R-squared (R²): 0.06324106616287706
# Adjusted R-squared (R²): 0.06211244094138646
# Mean Absolute Error (MAE): 0.03454278247919436
# Mean Absolute Percentage Error (MAPE): 1.990898616488345%

# %%
import pandas as pd

# Define the metrics for each category
metrics = ['MAE', 'MSE', 'RMSE', 'R2', 'Adjusted R2', 'MAPE']

# Define the values for each metric
NN_values = [mae_NN, mse_NN, rmse_NN, r2_NN, adjusted_r2_NN, mape_NN]
sh_values = [mae_NN_SH, mse_NN_SH, rmse_NN_SH, r2_NN_SH, adjusted_r2_NN_SH, mape_NN_SH]
dwh_values = [mae_NN_DWH, mse_NN_DWH, rmse_NN_DWH, r2_NN_DWH, adjusted_r2_NN_DWH, mape_NN_DWH]

# Create a dictionary to hold the data
data = {
    'Metric': metrics,
    'Total NN': NN_values,
    'SH NN': sh_values,
    'DWH NN': dwh_values
}

# Create a DataFrame
df_metrics = pd.DataFrame(data)

# Save the DataFrame to a CSV file
df_metrics.to_csv('NN_metrics.csv', index=False)

# Print the DataFrame to check
print(df_metrics)
# Out:
#         Metric  Total NN     SH NN    DWH NN
# 0          MAE  0.032802  0.029221  0.034543
# 1          MSE  0.001697  0.001504  0.001902
# 2         RMSE  0.041194  0.038785  0.043607
# 3           R2  0.164019  0.258958  0.063241
# 4  Adjusted R2  0.162002  0.258065  0.062112
# 5         MAPE  1.648073  1.531254  1.990899
