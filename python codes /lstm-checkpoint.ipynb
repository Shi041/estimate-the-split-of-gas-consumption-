# %% [markdown]
# # total

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# Load the data
daily_stat = pd.read_csv('hourly_stat.csv').dropna()

# Ensure the date column is parsed as datetime
daily_stat['date'] = pd.to_datetime(daily_stat['date'])

# Extract features and target
features = daily_stat[['SH_temp_mean', 'SH_hum_mean', 'DWH_temp_mean', 'DWH_hum_mean', 'ext_temp_mean', 'ext_hum_mean']]
target = daily_stat['Gas_mean']

# Normalize features
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Split data while keeping the date for plotting
X_train, X_test, y_train, y_test, date_train, date_test = train_test_split(features_scaled, target, daily_stat['date'], test_size=0.8, random_state=42)

# Ensure dates are sorted
date_test = pd.Series(date_test).sort_values().reset_index(drop=True)
date_train = pd.Series(date_train).sort_values().reset_index(drop=True)


# Reshape data for RNN input (samples, time steps, features)
X_train_rnn = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test_rnn = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

# Build RNN model
model = Sequential()
model.add(LSTM(192, input_shape=(X_train_rnn.shape[1], X_train_rnn.shape[2]), activation='relu', return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(32, activation='relu'))
model.add(Dense(8, activation='linear'))
model.add(Dense(4, activation='linear'))
model.add(Dense(1, activation='linear'))

# Compile model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train model
history = model.fit(X_train_rnn, y_train, epochs=100, batch_size=32, validation_split=0.2)

# Predict gas consumption on the test set
predictions = model.predict(X_test_rnn).flatten()

# Calculate evaluation metrics
mae = mean_absolute_error(y_test, predictions)
mse = mean_squared_error(y_test, predictions)
r2 = r2_score(y_test, predictions)
mape = mean_absolute_percentage_error(y_test, predictions)

print(f'Mean Absolute Error (MAE): {mae}')
print(f'Mean Squared Error (MSE): {mse}')
print(f'R-squared (R²): {r2}')
print(f'Mean Absolute Percentage Error (MAPE): {mape}%')



# Plot training loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# Compare actual vs predicted SH and DWH gas consumption
plt.figure(figsize=(14, 7))

plt.subplot(1, 2, 1)
plt.scatter(range(len(y_test)), y_test, label='Actual Total Gas Consumption')
plt.scatter(range(len(y_test)), predictions, label='Predicted Total Gas Consumption', alpha=0.7)
plt.title('Total Gas Consumption')
plt.xlabel('Sample')
plt.ylabel('Gas Consumption')
plt.legend()

plt.show()

# Plot actual vs predicted gas consumption over time
plt.figure(figsize=(14, 7))
plt.plot(date_test, y_test, label='Actual Gas Consumption', marker='o')
plt.plot(date_test, predictions, label='Predicted Gas Consumption', marker='x', linestyle='--')
plt.xlabel('Date')
plt.ylabel('Gas Consumption')
plt.title('Actual vs Predicted Gas Consumption')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Epoch 1/100
# 42/42 [==============================] - 2s 10ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 2/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 3/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 4/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 5/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 6/100
# 42/42 [==============================] - 0s 4ms/step - loss: 9.7234e-04 - val_loss: 0.0010
# Epoch 7/100
# 42/42 [==============================] - 0s 4ms/step - loss: 9.7729e-04 - val_loss: 0.0010
# Epoch 8/100
# 42/42 [==============================] - 0s 4ms/step - loss: 9.5098e-04 - val_loss: 0.0011
# Epoch 9/100
# 42/42 [==============================] - 0s 4ms/step - loss: 9.7460e-04 - val_loss: 0.0011
# Epoch 10/100
# 42/42 [==============================] - 0s 4ms/step - loss: 9.3262e-04 - val_loss: 0.0010
# Epoch 11/100
# 42/42 [==============================] - 0s 4ms/step - loss: 9.4102e-04 - val_loss: 9.9447e-04
# Epoch 12/100
# 42/42 [==============================] - 0s 4ms/step - loss: 9.6658e-04 - val_loss: 9.8815e-04
# Epoch 13/100
# 42/42 [==============================] - 0s 4ms/step - loss: 9.2935e-04 - val_loss: 0.0011
# Epoch 14/100
# 42/42 [==============================] - 0s 4ms/step - loss: 9.2076e-04 - val_loss: 0.0010
# Epoch 15/100
# 42/42 [==============================] - 0s 4ms/step - loss: 9.0889e-04 - val_loss: 0.0010
# Epoch 16/100
# 42/42 [==============================] - 0s 4ms/step - loss: 9.2332e-04 - val_loss: 0.0010
# Epoch 17/100
# 42/42 [==============================] - 0s 4ms/step - loss: 9.2930e-04 - val_loss: 0.0010
# Epoch 18/100
# 42/42 [==============================] - 0s 4ms/step - loss: 8.9001e-04 - val_loss: 0.0010
# Epoch 19/100
# 42/42 [==============================] - 0s 4ms/step - loss: 8.9432e-04 - val_loss: 0.0010
# Epoch 20/100
# 42/42 [==============================] - 0s 4ms/step - loss: 8.9933e-04 - val_loss: 0.0010
# Epoch 21/100
# 42/42 [==============================] - 0s 5ms/step - loss: 8.5655e-04 - val_loss: 0.0010
# Epoch 22/100
# 42/42 [==============================] - 0s 4ms/step - loss: 8.6936e-04 - val_loss: 9.8214e-04
# Epoch 23/100
# 42/42 [==============================] - 0s 4ms/step - loss: 8.7937e-04 - val_loss: 0.0010
# Epoch 24/100
# 42/42 [==============================] - 0s 4ms/step - loss: 8.7581e-04 - val_loss: 0.0011
# Epoch 25/100
# 42/42 [==============================] - 0s 4ms/step - loss: 8.7201e-04 - val_loss: 0.0011
# Epoch 26/100
# 42/42 [==============================] - 0s 4ms/step - loss: 8.4379e-04 - val_loss: 0.0011
# Epoch 27/100
# 42/42 [==============================] - 0s 4ms/step - loss: 8.1467e-04 - val_loss: 9.8650e-04
# Epoch 28/100
# 42/42 [==============================] - 0s 5ms/step - loss: 8.4732e-04 - val_loss: 0.0010
# Epoch 29/100
# 42/42 [==============================] - 0s 4ms/step - loss: 8.6251e-04 - val_loss: 0.0011
# Epoch 30/100
# 42/42 [==============================] - 0s 4ms/step - loss: 8.1451e-04 - val_loss: 9.9199e-04
# Epoch 31/100
# 42/42 [==============================] - 0s 4ms/step - loss: 8.3152e-04 - val_loss: 9.8639e-04
# Epoch 32/100
# 42/42 [==============================] - 0s 4ms/step - loss: 8.2011e-04 - val_loss: 0.0010
# Epoch 33/100
# 42/42 [==============================] - 0s 4ms/step - loss: 8.5469e-04 - val_loss: 9.9623e-04
# Epoch 34/100
# 42/42 [==============================] - 0s 5ms/step - loss: 8.3159e-04 - val_loss: 0.0011
# Epoch 35/100
# 42/42 [==============================] - 0s 4ms/step - loss: 8.2039e-04 - val_loss: 0.0010
# Epoch 36/100
# 42/42 [==============================] - 0s 4ms/step - loss: 7.9398e-04 - val_loss: 0.0010
# Epoch 37/100
# 42/42 [==============================] - 0s 4ms/step - loss: 8.0663e-04 - val_loss: 9.8921e-04
# Epoch 38/100
# 42/42 [==============================] - 0s 4ms/step - loss: 7.9552e-04 - val_loss: 9.8537e-04
# Epoch 39/100
# 42/42 [==============================] - 0s 4ms/step - loss: 7.9262e-04 - val_loss: 0.0010
# Epoch 40/100
# 42/42 [==============================] - 0s 4ms/step - loss: 8.0766e-04 - val_loss: 0.0011
# Epoch 41/100
# 42/42 [==============================] - 0s 4ms/step - loss: 7.9984e-04 - val_loss: 0.0011
# Epoch 42/100
# 42/42 [==============================] - 0s 4ms/step - loss: 7.8120e-04 - val_loss: 9.9726e-04
# Epoch 43/100
# 42/42 [==============================] - 0s 4ms/step - loss: 7.9159e-04 - val_loss: 0.0010
# Epoch 44/100
# 42/42 [==============================] - 0s 4ms/step - loss: 7.7695e-04 - val_loss: 9.9406e-04
# Epoch 45/100
# 42/42 [==============================] - 0s 4ms/step - loss: 7.7661e-04 - val_loss: 0.0010
# Epoch 46/100
# 42/42 [==============================] - 0s 4ms/step - loss: 7.6937e-04 - val_loss: 9.7339e-04
# Epoch 47/100
# 42/42 [==============================] - 0s 5ms/step - loss: 7.7071e-04 - val_loss: 0.0010
# Epoch 48/100
# 42/42 [==============================] - 0s 4ms/step - loss: 7.7600e-04 - val_loss: 0.0010
# Epoch 49/100
# 42/42 [==============================] - 0s 4ms/step - loss: 7.7367e-04 - val_loss: 0.0010
# Epoch 50/100
# 42/42 [==============================] - 0s 4ms/step - loss: 7.7614e-04 - val_loss: 9.7138e-04
# Epoch 51/100
# 42/42 [==============================] - 0s 4ms/step - loss: 7.4651e-04 - val_loss: 9.9963e-04
# Epoch 52/100
# 42/42 [==============================] - 0s 4ms/step - loss: 7.3430e-04 - val_loss: 0.0010
# Epoch 53/100
# 42/42 [==============================] - 0s 4ms/step - loss: 7.5974e-04 - val_loss: 0.0010
# Epoch 54/100
# 42/42 [==============================] - 0s 4ms/step - loss: 7.5424e-04 - val_loss: 0.0011
# Epoch 55/100
# 42/42 [==============================] - 0s 5ms/step - loss: 7.5834e-04 - val_loss: 0.0011
# Epoch 56/100
# 42/42 [==============================] - 0s 4ms/step - loss: 7.4976e-04 - val_loss: 0.0010
# Epoch 57/100
# 42/42 [==============================] - 0s 4ms/step - loss: 7.2143e-04 - val_loss: 0.0010
# Epoch 58/100
# 42/42 [==============================] - 0s 4ms/step - loss: 7.2421e-04 - val_loss: 0.0010
# Epoch 59/100
# 42/42 [==============================] - 0s 4ms/step - loss: 7.3091e-04 - val_loss: 0.0010
# Epoch 60/100
# 42/42 [==============================] - 0s 4ms/step - loss: 7.4963e-04 - val_loss: 0.0010
# Epoch 61/100
# 42/42 [==============================] - 0s 4ms/step - loss: 7.4448e-04 - val_loss: 0.0010
# Epoch 62/100
# 42/42 [==============================] - 0s 4ms/step - loss: 7.1676e-04 - val_loss: 0.0010
# Epoch 63/100
# 42/42 [==============================] - 0s 4ms/step - loss: 7.0222e-04 - val_loss: 0.0010
# Epoch 64/100
# 42/42 [==============================] - 0s 4ms/step - loss: 7.0271e-04 - val_loss: 0.0010
# Epoch 65/100
# 42/42 [==============================] - 0s 4ms/step - loss: 7.1753e-04 - val_loss: 0.0010
# Epoch 66/100
# 42/42 [==============================] - 0s 4ms/step - loss: 7.0251e-04 - val_loss: 0.0010
# Epoch 67/100
# 42/42 [==============================] - 0s 4ms/step - loss: 7.0908e-04 - val_loss: 0.0011
# Epoch 68/100
# 42/42 [==============================] - 0s 4ms/step - loss: 7.3400e-04 - val_loss: 0.0010
# Epoch 69/100
# 42/42 [==============================] - 0s 4ms/step - loss: 7.0287e-04 - val_loss: 0.0011
# Epoch 70/100
# 42/42 [==============================] - 0s 4ms/step - loss: 6.6356e-04 - val_loss: 0.0010
# Epoch 71/100
# 42/42 [==============================] - 0s 5ms/step - loss: 6.8125e-04 - val_loss: 0.0011
# Epoch 72/100
# 42/42 [==============================] - 0s 5ms/step - loss: 6.9108e-04 - val_loss: 0.0011
# Epoch 73/100
# 42/42 [==============================] - 0s 4ms/step - loss: 6.7982e-04 - val_loss: 0.0011
# Epoch 74/100
# 42/42 [==============================] - 0s 4ms/step - loss: 6.9681e-04 - val_loss: 0.0010
# Epoch 75/100
# 42/42 [==============================] - 0s 4ms/step - loss: 6.7038e-04 - val_loss: 0.0010
# Epoch 76/100
# 42/42 [==============================] - 0s 4ms/step - loss: 6.8847e-04 - val_loss: 9.9781e-04
# Epoch 77/100
# 42/42 [==============================] - 0s 5ms/step - loss: 6.7245e-04 - val_loss: 0.0011
# Epoch 78/100
# 42/42 [==============================] - 0s 4ms/step - loss: 6.5847e-04 - val_loss: 0.0011
# Epoch 79/100
# 42/42 [==============================] - 0s 5ms/step - loss: 6.5947e-04 - val_loss: 0.0010
# Epoch 80/100
# 42/42 [==============================] - 0s 5ms/step - loss: 6.9223e-04 - val_loss: 0.0010
# Epoch 81/100
# 42/42 [==============================] - 0s 5ms/step - loss: 6.6946e-04 - val_loss: 0.0010
# Epoch 82/100
# 42/42 [==============================] - 0s 4ms/step - loss: 6.6812e-04 - val_loss: 0.0010
# Epoch 83/100
# 42/42 [==============================] - 0s 5ms/step - loss: 6.7438e-04 - val_loss: 0.0010
# Epoch 84/100
# 42/42 [==============================] - 0s 4ms/step - loss: 6.3995e-04 - val_loss: 0.0010
# Epoch 85/100
# 42/42 [==============================] - 0s 5ms/step - loss: 6.6261e-04 - val_loss: 0.0010
# Epoch 86/100
# 42/42 [==============================] - 0s 5ms/step - loss: 6.3837e-04 - val_loss: 0.0011
# Epoch 87/100
# 42/42 [==============================] - 0s 4ms/step - loss: 6.5137e-04 - val_loss: 0.0010
# Epoch 88/100
# 42/42 [==============================] - 0s 4ms/step - loss: 6.4270e-04 - val_loss: 0.0012
# Epoch 89/100
# 42/42 [==============================] - 0s 4ms/step - loss: 6.4156e-04 - val_loss: 0.0010
# Epoch 90/100
# 42/42 [==============================] - 0s 4ms/step - loss: 6.6140e-04 - val_loss: 0.0012
# Epoch 91/100
# 42/42 [==============================] - 0s 4ms/step - loss: 6.4530e-04 - val_loss: 0.0010
# Epoch 92/100
# 42/42 [==============================] - 0s 4ms/step - loss: 6.5755e-04 - val_loss: 9.9759e-04
# Epoch 93/100
# 42/42 [==============================] - 0s 5ms/step - loss: 6.3348e-04 - val_loss: 0.0011
# Epoch 94/100
# 42/42 [==============================] - 0s 4ms/step - loss: 6.0933e-04 - val_loss: 0.0012
# Epoch 95/100
# 42/42 [==============================] - 0s 4ms/step - loss: 6.3599e-04 - val_loss: 0.0010
# Epoch 96/100
# 42/42 [==============================] - 0s 4ms/step - loss: 6.4177e-04 - val_loss: 0.0010
# Epoch 97/100
# 42/42 [==============================] - 0s 4ms/step - loss: 6.0784e-04 - val_loss: 0.0010
# Epoch 98/100
# 42/42 [==============================] - 0s 4ms/step - loss: 6.2608e-04 - val_loss: 9.7484e-04
# Epoch 99/100
# 42/42 [==============================] - 0s 4ms/step - loss: 6.1584e-04 - val_loss: 0.0011
# Epoch 100/100
# 42/42 [==============================] - 0s 4ms/step - loss: 6.2665e-04 - val_loss: 9.8122e-04
# 208/208 [==============================] - 1s 1ms/step
# Mean Absolute Error (MAE): 0.022453618993203837
# Mean Squared Error (MSE): 0.0009699318429309731
# R-squared (R²): 0.5142763191821071
# Mean Absolute Percentage Error (MAPE): 0.9593332220554389%

# %% [markdown]
# # SH

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# Load the data
daily_stat = pd.read_csv('hourly_stat.csv').dropna()

# Ensure the date column is parsed as datetime
daily_stat['date'] = pd.to_datetime(daily_stat['date'])

# Extract features and target
features = daily_stat[['SH_temp_mean', 'SH_hum_mean']]
target = daily_stat['Gas_mean']

# Normalize features
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Split data while keeping the date for plotting
X_train, X_test, y_train, y_test, date_train, date_test = train_test_split(features_scaled, target, daily_stat['date'], test_size=0.8, random_state=42)

# Ensure dates are sorted
date_test = pd.Series(date_test).sort_values().reset_index(drop=True)
date_train = pd.Series(date_train).sort_values().reset_index(drop=True)


# Reshape data for RNN input (samples, time steps, features)
X_train_rnn = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test_rnn = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

# Build RNN model
model = Sequential()
model.add(LSTM(192, input_shape=(X_train_rnn.shape[1], X_train_rnn.shape[2]), activation='relu', return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(32, activation='relu'))
model.add(Dense(8, activation='linear'))
model.add(Dense(4, activation='linear'))
model.add(Dense(1, activation='linear'))

# Compile model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train model
history = model.fit(X_train_rnn, y_train, epochs=100, batch_size=32, validation_split=0.2)

# Predict gas consumption on the test set
SH_predictions = model.predict(X_test_rnn).flatten()

# Calculate evaluation metrics
mae = mean_absolute_error(y_test, SH_predictions)
mse = mean_squared_error(y_test, SH_predictions)
r2 = r2_score(y_test, SH_predictions)
mape = mean_absolute_percentage_error(y_test, SH_predictions)

print(f'Mean Absolute Error (MAE): {mae}')
print(f'Mean Squared Error (MSE): {mse}')
print(f'R-squared (R²): {r2}')
print(f'Mean Absolute Percentage Error (MAPE): {mape}%')



# Plot training loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# Compare actual vs predicted SH and DWH gas consumption
plt.figure(figsize=(14, 7))

plt.subplot(1, 2, 1)
plt.scatter(range(len(y_test)), y_test, label='Actual Total Gas Consumption')
plt.scatter(range(len(y_test)), SH_predictions, label='Predicted Total Gas Consumption', alpha=0.7)
plt.title('Total Gas Consumption')
plt.xlabel('Sample')
plt.ylabel('Gas Consumption')
plt.legend()

plt.show()

# Plot actual vs predicted gas consumption over time
plt.figure(figsize=(14, 7))
plt.plot(date_test, y_test, label='Actual Gas Consumption', marker='o')
plt.plot(date_test, SH_predictions, label='Predicted Gas Consumption', marker='x', linestyle='--')
plt.xlabel('Date')
plt.ylabel('Gas Consumption')
plt.title('Actual vs Predicted Gas Consumption')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import math

# Calculate evaluation metrics
mae_LSTM_SH  = mean_absolute_error(y_test, SH_predictions)
mse_LSTM_SH = mean_squared_error(y_test, SH_predictions)
rmse_LSTM_SH= math.sqrt(mse)
r2_LSTM_SH = r2_score(y_test, SH_predictions)
n = len(y_test)
p = X_test.shape[1]
adjusted_r2_LSTM_SH = 1 - (1 - r2) * (n - 1) / (n - p - 1)
mape_LSTM_SH = mean_absolute_percentage_error(y_test, SH_predictions)

print(f'Mean Squared Error (MSE): {mae_LSTM_SH }')
print(f'Root Mean Squared Error (RMSE): {mse_LSTM_SH }')
print(f'R-squared (R²): {r2_LSTM_SH }')
print(f'Adjusted R-squared (R²): {adjusted_r2_LSTM_SH }')

print(f'Mean Absolute Error (MAE): {mae_LSTM_SH }')
print(f'Mean Absolute Percentage Error (MAPE): {mape_LSTM_SH }%')

# %% [markdown]
# # DWH

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# Load the data
daily_stat = pd.read_csv('hourly_stat.csv').dropna()

# Ensure the date column is parsed as datetime
daily_stat['date'] = pd.to_datetime(daily_stat['date'])

# Extract features and target
features = daily_stat[[ 'DWH_temp_mean', 'DWH_hum_mean']]
target = daily_stat['Gas_mean']

# Normalize features
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Split data while keeping the date for plotting
X_train, X_test, y_train, y_test, date_train, date_test = train_test_split(features_scaled, target, daily_stat['date'], test_size=0.8, random_state=42)

# Ensure dates are sorted
date_test = pd.Series(date_test).sort_values().reset_index(drop=True)
date_train = pd.Series(date_train).sort_values().reset_index(drop=True)


# Reshape data for RNN input (samples, time steps, features)
X_train_rnn = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test_rnn = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

# Build RNN model
model = Sequential()
model.add(LSTM(192, input_shape=(X_train_rnn.shape[1], X_train_rnn.shape[2]), activation='relu', return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(32, activation='relu'))
model.add(Dense(8, activation='linear'))
model.add(Dense(4, activation='linear'))
model.add(Dense(1, activation='linear'))

# Compile model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train model
history = model.fit(X_train_rnn, y_train, epochs=100, batch_size=32, validation_split=0.2)

# Predict gas consumption on the test set
DWH_predictions = model.predict(X_test_rnn).flatten()

# Calculate evaluation metrics
mae = mean_absolute_error(y_test, DWH_predictions)
mse = mean_squared_error(y_test, DWH_predictions)
r2 = r2_score(y_test, DWH_predictions)
mape = mean_absolute_percentage_error(y_test, DWH_predictions)

print(f'Mean Absolute Error (MAE): {mae}')
print(f'Mean Squared Error (MSE): {mse}')
print(f'R-squared (R²): {r2}')
print(f'Mean Absolute Percentage Error (MAPE): {mape}%')



# Plot training loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# Compare actual vs predicted SH and DWH gas consumption
plt.figure(figsize=(14, 7))

plt.subplot(1, 2, 1)
plt.scatter(range(len(y_test)), y_test, label='Actual Total Gas Consumption')
plt.scatter(range(len(y_test)), DWH_predictions, label='Predicted Total Gas Consumption', alpha=0.7)
plt.title('Total Gas Consumption')
plt.xlabel('Sample')
plt.ylabel('Gas Consumption')
plt.legend()

plt.show()

# Plot actual vs predicted gas consumption over time
plt.figure(figsize=(14, 7))
plt.plot(date_test, y_test, label='Actual Gas Consumption', marker='o')
plt.plot(date_test, DWH_predictions, label='Predicted Gas Consumption', marker='x', linestyle='--')
plt.xlabel('Date')
plt.ylabel('Gas Consumption')
plt.title('Actual vs Predicted Gas Consumption')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Epoch 1/100
# 42/42 [==============================] - 3s 11ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 2/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 3/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 4/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 5/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 6/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 7/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 8/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 9/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 10/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 11/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 12/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 13/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 14/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 15/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 16/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 17/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 18/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 19/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 20/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 21/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 22/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 23/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 24/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 25/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 26/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 27/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 28/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 29/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 30/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 31/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 32/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 33/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 34/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 35/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 36/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 37/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 38/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 39/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 40/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 41/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 42/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 43/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 44/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 45/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 46/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 47/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 48/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 49/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 50/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 51/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 52/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 53/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 54/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 55/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 56/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 57/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 58/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 59/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 60/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 61/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 62/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 63/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 64/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 65/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 66/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 67/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 68/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 69/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 70/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 71/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 72/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 73/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 74/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 75/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 76/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 77/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 78/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 79/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 80/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 81/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 82/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 83/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 84/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 85/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 86/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 87/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 88/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 89/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 90/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 91/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 92/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 93/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 94/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 95/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 96/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 97/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 98/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 99/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 100/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0014
# 208/208 [==============================] - 1s 1ms/step
# Mean Absolute Error (MAE): 0.028522979256609845
# Mean Squared Error (MSE): 0.0014517487852978661
# R-squared (R²): 0.2729914284627033
# Mean Absolute Percentage Error (MAPE): 1.3291794941314%

# %%
import math

# Calculate evaluation metrics
mae_LSTM_DWH  = mean_absolute_error(y_test, DWH_predictions)
mse_LSTM_DWH = mean_squared_error(y_test, DWH_predictions)
rmse_LSTM_DWH= math.sqrt(mse)
r2_LSTM_DWH = r2_score(y_test, DWH_predictions)
n = len(y_test)
p = X_test.shape[1]
adjusted_r2_LSTM_DWH = 1 - (1 - r2) * (n - 1) / (n - p - 1)
mape_LSTM_DWH = mean_absolute_percentage_error(y_test, DWH_predictions)

print(f'Mean Squared Error (MSE): {mae_LSTM_DWH }')
print(f'Root Mean Squared Error (RMSE): {mse_LSTM_DWH }')
print(f'R-squared (R²): {r2_LSTM_DWH }')
print(f'Adjusted R-squared (R²): {adjusted_r2_LSTM_DWH }')

print(f'Mean Absolute Error (MAE): {mae_LSTM_DWH }')
print(f'Mean Absolute Percentage Error (MAPE): {mape_LSTM_DWH }%')
# Out:
# Mean Squared Error (MSE): 0.028522979256609845
# Root Mean Squared Error (RMSE): 0.0014517487852978661
# R-squared (R²): 0.2729914284627033
# Adjusted R-squared (R²): 0.2727726805850029
# Mean Absolute Error (MAE): 0.028522979256609845
# Mean Absolute Percentage Error (MAPE): 1.3291794941314%
