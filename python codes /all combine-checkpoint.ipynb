# %%
#!pip install pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
HH1_ALL = pd.read_csv('data\HH01_all1.csv')

# %%
HH1_ALL = pd.read_csv('data\HH01_all1.csv')
HH2_ALL = pd.read_csv('data\HH02_all1.csv')
HH3_ALL = pd.read_csv('data\HH03_all1.csv')
HH4_ALL = pd.read_csv('data\HH04_all1.csv')
HH5_ALL = pd.read_csv('data\HH05_all1.csv')
HH6_ALL = pd.read_csv('data\HH06_all1.csv')
HH7_ALL = pd.read_csv('data\HH07_all1.csv')
HH8_ALL = pd.read_csv('data\HH08_all1.csv')
HH9_ALL = pd.read_csv('data\HH09_all1.csv')
HH10_ALL = pd.read_csv('data\HH10_all1.csv')
HH11_ALL = pd.read_csv('data\HH11_all1.csv')
HH12_ALL = pd.read_csv('data\HH12_all1.csv')
HH13_ALL = pd.read_csv('data\HH13_all1.csv')
HH14_ALL = pd.read_csv('data\HH14_all1.csv')
HH15_ALL = pd.read_csv('data\HH15_all1.csv')
HH16_ALL = pd.read_csv('data\HH16_all1.csv')
HH17_ALL = pd.read_csv('data\HH17_all1.csv')
HH18_ALL = pd.read_csv('data\HH18_all1.csv')
HH19_ALL = pd.read_csv('data\HH19_all1.csv')
HH20_ALL = pd.read_csv('data\HH20_all1.csv')
HH21_ALL = pd.read_csv('data\HH21_all1.csv')
HH22_ALL = pd.read_csv('data\HH22_all1.csv')
HH23_ALL = pd.read_csv('data\HH23_all1.csv')
HH24_ALL = pd.read_csv('data\HH24_all1.csv')
HH25_ALL = pd.read_csv('data\HH25_all1.csv')
HH26_ALL = pd.read_csv('data\HH26_all1.csv')
HH27_ALL = pd.read_csv('data\HH27_all1.csv')
HH28_ALL = pd.read_csv('data\HH28_all1.csv')
HH29_ALL = pd.read_csv('data\HH29_all1.csv')
HH30_ALL = pd.read_csv('data\HH30_all1.csv')

# %%
file_paths = [f'data/HH{i:02d}_all1.csv' for i in range(1, 3)]

# %%
dataframes = []

# %%
# Load and rename columns for each DataFrame
for i, file_path in enumerate(file_paths, start=1):
    df = pd.read_csv(file_path)
    df.rename(columns={'Unnamed: 0': 'date'}, inplace=True)
    df.columns = [f'{col}_{i}' if col != 'date' else col for col in df.columns]
    dataframes.append(df)

# %%
# Example of how to access a DataFrame and its columns
for i, df in enumerate(dataframes):
    print(f'DataFrame {i+1} columns: {df.columns.tolist()}')
# Out:
# DataFrame 1 columns: ['date', 'Elec kWh_1', 'Gas m3_1', 'backbed_hum_1', 'backbed_temp_1', 'bath_hum_1', 'bath_temp_1', 'frontbed_hum_1', 'frontbed_temp_1', 'hall_hum_1', 'hall_temp_1', 'kit_hum_1', 'kit_temp_1', 'liv_hum_1', 'liv_temp_1', 'Wind direction (from N)_1', 'Windspeed (m/s)_1', 'Rainfall (mm)_1', 'Air temp (degC)_1', 'RH (%)_1', 'Atmos press (hPa)_1', 'Solar_vert_south (W/m2)_1']
# DataFrame 2 columns: ['date', 'Elec kWh_2', 'Gas m3_2', 'bath_hum_2', 'bath_temp_2', 'bed_hum_2', 'bed_temp_2', 'hall_hum_2', 'hall_temp_2', 'kit_hum_2', 'kit_temp_2', 'liv_hum_2', 'liv_temp_2', 'Wind direction (from N)_2', 'Windspeed (m/s)_2', 'Rainfall (mm)_2', 'Air temp (degC)_2', 'RH (%)_2', 'Atmos press (hPa)_2', 'Solar_vert_south (W/m2)_2']

# %%
combined_df = pd.concat(dataframes, axis=1)  # This concatenates along columns; use axis=0 to concatenate along rows

# %%
combined_df.dtypes
# Out:
# date                          object
# Elec kWh_1                   float64
# Gas m3_1                     float64
# backbed_hum_1                float64
# backbed_temp_1               float64
# bath_hum_1                   float64
# bath_temp_1                  float64
# frontbed_hum_1               float64
# frontbed_temp_1              float64
# hall_hum_1                   float64
# hall_temp_1                  float64
# kit_hum_1                    float64
# kit_temp_1                   float64
# liv_hum_1                    float64
# liv_temp_1                   float64
# Wind direction (from N)_1    float64
# Windspeed (m/s)_1            float64
# Rainfall (mm)_1              float64
# Air temp (degC)_1            float64
# RH (%)_1                     float64
# Atmos press (hPa)_1          float64
# Solar_vert_south (W/m2)_1    float64
# date                          object
# Elec kWh_2                   float64
# Gas m3_2                     float64
# bath_hum_2                   float64
# bath_temp_2                  float64
# bed_hum_2                    float64
# bed_temp_2                   float64
# hall_hum_2                   float64
# hall_temp_2                  float64
# kit_hum_2                    float64
# kit_temp_2                   float64
# liv_hum_2                    float64
# liv_temp_2                   float64
# Wind direction (from N)_2    float64
# Windspeed (m/s)_2            float64
# Rainfall (mm)_2              float64
# Air temp (degC)_2            float64
# RH (%)_2                     float64
# Atmos press (hPa)_2          float64
# Solar_vert_south (W/m2)_2    float64
# dtype: object

# %%
combined_df['date'].head()
# Out:
#                date              date
# 0  03/03/2020 00:00  05/03/2020 00:00
# 1  03/03/2020 00:30  05/03/2020 00:30
# 2  03/03/2020 01:00  05/03/2020 01:00
# 3  03/03/2020 01:30  05/03/2020 01:30
# 4  03/03/2020 02:00  05/03/2020 02:00

# %%
import pandas as pd

# List of file paths
file_paths = [f'data/HH{i:02d}_all1.csv' for i in range(1, 3)]

# Words to filter out
filter_words = ['wind', 'rain', 'solar', 'hpa']

# Dictionary to store DataFrames
dataframes = {}

# Load and rename columns for each DataFrame
for i, file_path in enumerate(file_paths, start=1):
    df = pd.read_csv(file_path)
    # Rename 'Unnamed: 0' to 'date'
    df.rename(columns={'Unnamed: 0': 'date'}, inplace=True)
    # Rename other columns to include file identifier
   # df.columns = [f'{col}_{i}' if col != 'date' else col for col in df.columns]
    # Filter out columns containing any of the filter words
    df = df[[col for col in df.columns if not any(word in col.lower() for word in filter_words)]]
    # Set 'date' as index
    df.set_index('date', inplace=True)
    # Store DataFrame in dictionary
    dataframes[i] = df

# Combine all DataFrames on the 'date' index using outer join
combined_df = pd.concat(dataframes.values(), axis=1, join='inner')

# Display the combined DataFrame
combined_df.head()
# Out:
#                   Elec kWh  Gas m3  backbed_hum  backbed_temp  bath_hum  \
# date
# 05/03/2020 00:00     0.088  -0.001         48.5         23.62       NaN
# 05/03/2020 00:30     0.121   0.000         47.0         23.76       NaN
# 05/03/2020 01:00     0.170   0.000         48.1         23.61       NaN
# 05/03/2020 01:30     0.165   0.000         47.4         23.62       NaN
# 05/03/2020 02:00     0.161   0.000         46.4         23.89       NaN
#
#                   bath_temp  frontbed_hum  frontbed_temp  hall_hum  hall_temp  \
# date
# 05/03/2020 00:00        NaN          50.2          22.19      44.6      22.64
# 05/03/2020 00:30        NaN          50.0          22.23      44.7      22.65
# 05/03/2020 01:00        NaN          50.5          21.60      44.5      22.31
# 05/03/2020 01:30        NaN          50.6          21.94      43.7      22.16
# 05/03/2020 02:00        NaN          50.7          21.99      43.2      22.11
#
#                   ...  bed_hum  bed_temp  hall_hum  hall_temp  kit_hum  \
# date              ...
# 05/03/2020 00:00  ...    39.43     24.93     38.30      25.10    37.68
# 05/03/2020 00:30  ...    38.82     24.98     38.55      25.27    37.96
# 05/03/2020 01:00  ...    39.75     25.02     38.01      25.34    37.46
# 05/03/2020 01:30  ...    39.94     25.10     38.07      25.45    37.64
# 05/03/2020 02:00  ...    37.05     24.99     35.60      25.33    35.16
#
#                   kit_temp  liv_hum  liv_temp  Air temp (degC)     RH (%)
# date
# 05/03/2020 00:00     24.76    38.88     25.24         3.400000  84.000000
# 05/03/2020 00:30     24.79    39.49     25.38         2.633333  85.333333
# 05/03/2020 01:00     24.79    39.22     25.42         2.100000  88.333333
# 05/03/2020 01:30     24.82    37.39     25.47         2.066667  89.333333
# 05/03/2020 02:00     24.82    36.54     25.48         2.033333  89.333333
#
# [5 rows x 30 columns]

# %%
#plt.plot(combined_df['bath_temp'])
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 2
#       1 plt.plot(combined_df['bath_temp'])
# ----> 2 plt.show()
#
# File F:\anaconda\Lib\site-packages\matplotlib\pyplot.py:446, in show(*args, **kwargs)
#     402 """
#     403 Display all open figures.
#     404
#    (...)
#     443 explicitly there.
#     444 """
#     445 _warn_if_gui_out_of_main_thread()
# --> 446 return _get_backend_mod().show(*args, **kwargs)
#
# File F:\anaconda\Lib\site-packages\matplotlib_inline\backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File F:\anaconda\Lib\site-packages\IPython\core\display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File F:\anaconda\Lib\site-packages\IPython\core\formatters.py:179, in DisplayFormatter.format(self, obj, include, exclude)
#     177 md = None
#     178 try:
# --> 179     data = formatter(obj)
#     180 except:
#     181     # FIXME: log the exception
#     182     raise
#
# File F:\anaconda\Lib\site-packages\decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File F:\anaconda\Lib\site-packages\IPython\core\formatters.py:223, in catch_format_error(method, self, *args, **kwargs)
#     221 """show traceback on failed format call"""
#     222 try:
# --> 223     r = method(self, *args, **kwargs)
#     224 except NotImplementedError:
#     225     # don't warn on NotImplementedErrors
#     226     return self._check_return(None, args[0])
#
# File F:\anaconda\Lib\site-packages\IPython\core\formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File F:\anaconda\Lib\site-packages\IPython\core\pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File F:\anaconda\Lib\site-packages\matplotlib\backend_bases.py:2346, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2344 if bbox_inches:
#    2345     if bbox_inches == "tight":
# -> 2346         bbox_inches = self.figure.get_tightbbox(
#    2347             renderer, bbox_extra_artists=bbox_extra_artists)
#    2348         if pad_inches is None:
#    2349             pad_inches = rcParams['savefig.pad_inches']
#
# File F:\anaconda\Lib\site-packages\matplotlib\figure.py:1753, in FigureBase.get_tightbbox(self, renderer, bbox_extra_artists)
#    1749 if ax.get_visible():
#    1750     # some axes don't take the bbox_extra_artists kwarg so we
#    1751     # need this conditional....
#    1752     try:
# -> 1753         bbox = ax.get_tightbbox(
#    1754             renderer, bbox_extra_artists=bbox_extra_artists)
#    1755     except TypeError:
#    1756         bbox = ax.get_tightbbox(renderer)
#
# File F:\anaconda\Lib\site-packages\matplotlib\axes\_base.py:4408, in _AxesBase.get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4405     bbox_artists = self.get_default_bbox_extra_artists()
#    4407 for a in bbox_artists:
# -> 4408     bbox = a.get_tightbbox(renderer)
#    4409     if (bbox is not None
#    4410             and 0 < bbox.width < np.inf
#    4411             and 0 < bbox.height < np.inf):
#    4412         bb.append(bbox)
#
# File F:\anaconda\Lib\site-packages\matplotlib\artist.py:367, in Artist.get_tightbbox(self, renderer)
#     352 def get_tightbbox(self, renderer=None):
#     353     """
#     354     Like `.Artist.get_window_extent`, but includes any clipping.
#     355
#    (...)
#     365         The enclosing bounding box (in figure pixel coordinates).
#     366     """
# --> 367     bbox = self.get_window_extent(renderer)
#     368     if self.get_clip_on():
#     369         clip_box = self.get_clip_box()
#
# File F:\anaconda\Lib\site-packages\matplotlib\spines.py:158, in Spine.get_window_extent(self, renderer)
#     156     return bb
#     157 bboxes = [bb]
# --> 158 drawn_ticks = self.axis._update_ticks()
#     160 major_tick = next(iter({*drawn_ticks} & {*self.axis.majorTicks}), None)
#     161 minor_tick = next(iter({*drawn_ticks} & {*self.axis.minorTicks}), None)
#
# File F:\anaconda\Lib\site-packages\matplotlib\axis.py:1267, in Axis._update_ticks(self)
#    1265 self.major.formatter.set_locs(major_locs)
#    1266 for tick, loc, label in zip(major_ticks, major_locs, major_labels):
# -> 1267     tick.update_position(loc)
#    1268     tick.set_label1(label)
#    1269     tick.set_label2(label)
#
# File F:\anaconda\Lib\site-packages\matplotlib\axis.py:459, in XTick.update_position(self, loc)
#     457 self.tick1line.set_xdata((loc,))
#     458 self.tick2line.set_xdata((loc,))
# --> 459 self.gridline.set_xdata((loc,))
#     460 self.label1.set_x(loc)
#     461 self.label2.set_x(loc)
#
# File F:\anaconda\Lib\site-packages\matplotlib\lines.py:1286, in Line2D.set_xdata(self, x)
#    1280     _api.warn_deprecated(
#    1281         since=3.7,
#    1282         message="Setting data with a non sequence type "
#    1283         "is deprecated since %(since)s and will be "
#    1284         "remove %(removal)s")
#    1285     x = [x, ]
# -> 1286 self._xorig = copy.copy(x)
#    1287 self._invalidx = True
#    1288 self.stale = True
#
# File F:\anaconda\Lib\copy.py:76, in copy(x)
#      74 copier = _copy_dispatch.get(cls)
#      75 if copier:
# ---> 76     return copier(x)
#      78 if issubclass(cls, type):
#      79     # treat it as a regular class:
#      80     return _copy_immutable(x)
#
# File F:\anaconda\Lib\copy.py:107, in _copy_immutable(x)
#     102     return _reconstruct(x, None, *rv)
#     105 _copy_dispatch = d = {}
# --> 107 def _copy_immutable(x):
#     108     return x
#     109 for t in (type(None), int, float, bool, complex, str, tuple,
#     110           bytes, frozenset, type, range, slice, property,
#     111           types.BuiltinFunctionType, type(Ellipsis), type(NotImplemented),
#     112           types.FunctionType, weakref.ref):
#
# KeyboardInterrupt:

# %%
import pandas as pd

# List of file paths
file_paths = [f'data/HH{i:02d}_all1.csv' for i in range(1, 31)]

# Words to filter out
filter_words = ['wind', 'rain', 'solar', 'hpa']

# Dictionary to store DataFrames
dataframes = {}

# Load and rename columns for each DataFrame
for i, file_path in enumerate(file_paths, start=1):
    df = pd.read_csv(file_path)
    # Rename 'Unnamed: 0' to 'date'
    df.rename(columns={'Unnamed: 0': 'date'}, inplace=True)
    # Rename other columns to include file identifier
    df.columns = [f'{col}_{i}' if col != 'date' else col for col in df.columns]
    # Filter out columns containing any of the filter words
    df = df[[col for col in df.columns if not any(word in col.lower() for word in filter_words)]]
    # Set 'date' as index
    df.set_index('date', inplace=True)
    # Store DataFrame in dictionary
    dataframes[i] = df

# Combine all DataFrames on the 'date' index using outer join
combined_df = pd.concat(dataframes.values(), axis=1, join='inner')

# Find the mean value for each group of similar columns
mean_df = pd.DataFrame(index=combined_df.index)

# Group columns by their base name (before the suffix)
for base_col in set(col.rsplit('_', 1)[0] for col in combined_df.columns):
    similar_cols = [col for col in combined_df.columns if col.startswith(base_col)]
    if similar_cols:
        mean_df[f'{base_col}_mean'] = combined_df[similar_cols].mean(axis=1)

# Display the DataFrame with mean values
mean_df.dtypes
# Out:
# bath_temp_mean                 float64
# backroom_hum_mean              float64
# mediumbed_temp_mean            float64
# box_temp_mean                  float64
# backroom_temp_mean             float64
# kit_hum_mean                   float64
# bed_temp_mean                  float64
# toilet_hum_mean                float64
# mediumbed_hum_mean             float64
# hall_temp_mean                 float64
# util_temp_mean                 float64
# kit_temp_mean                  float64
# rearbed_temp_mean              float64
# rightbed_hum_mean              float64
# liv_temp_mean                  float64
# rightbed_temp_mean             float64
# hall_hum_mean                  float64
# toilet_temp_mean               float64
# Gas m3_mean                    float64
# backbed_hum_mean               float64
# masterbed_hum_mean             float64
# Air temp (degC)_mean           float64
# RH (%)_mean                    float64
# liv_hum_mean                   float64
# frontbedabovedoor_hum_mean     float64
# Elec kWh_mean                  float64
# frontbedabovedoor_temp_mean    float64
# dining_hum_mean                float64
# leftbed_hum_mean               float64
# smallliv_hum_mean              float64
# masterbed_temp_mean            float64
# smallbed_temp_mean             float64
# frontbed_temp_mean             float64
# smallliv_temp_mean             float64
# bed_hum_mean                   float64
# util_hum_mean                  float64
# smallbed_hum_mean              float64
# dining_temp_mean               float64
# bath_hum_mean                  float64
# box_hum_mean                   float64
# rearbed_hum_mean               float64
# frontbed_hum_mean              float64
# leftbed_temp_mean              float64
# backbed_temp_mean              float64
# dtype: object

# %%
plt.plot(mean_df['Gas m3_mean'].head(300))
plt.show()

# %%
memory_usage = mean_df.memory_usage(deep=True)
total_memory = memory_usage.sum()

print("Memory usage by column (in bytes):")
print(memory_usage)
print(f"Total memory usage: {total_memory / (1024 ** 2):.2f} MB")
# Out:
# Memory usage by column (in bytes):
# Index                          1349040
# bath_temp_mean                  147840
# backroom_hum_mean               147840
# mediumbed_temp_mean             147840
# box_temp_mean                   147840
# backroom_temp_mean              147840
# kit_hum_mean                    147840
# bed_temp_mean                   147840
# toilet_hum_mean                 147840
# mediumbed_hum_mean              147840
# hall_temp_mean                  147840
# util_temp_mean                  147840
# kit_temp_mean                   147840
# rearbed_temp_mean               147840
# rightbed_hum_mean               147840
# liv_temp_mean                   147840
# rightbed_temp_mean              147840
# hall_hum_mean                   147840
# toilet_temp_mean                147840
# Gas m3_mean                     147840
# backbed_hum_mean                147840
# masterbed_hum_mean              147840
# Air temp (degC)_mean            147840
# RH (%)_mean                     147840
# liv_hum_mean                    147840
# frontbedabovedoor_hum_mean      147840
# Elec kWh_mean                   147840
# frontbedabovedoor_temp_mean     147840
# dining_hum_mean                 147840
# leftbed_hum_mean                147840
# smallliv_hum_mean               147840
# masterbed_temp_mean             147840
# smallbed_temp_mean              147840
# frontbed_temp_mean              147840
# smallliv_temp_mean              147840
# bed_hum_mean                    147840
# util_hum_mean                   147840
# smallbed_hum_mean               147840
# dining_temp_mean                147840
# bath_hum_mean                   147840
# box_hum_mean                    147840
# rearbed_hum_mean                147840
# frontbed_hum_mean               147840
# leftbed_temp_mean               147840
# backbed_temp_mean               147840
# dtype: int64
# Total memory usage: 7.49 MB

# %%
mean_df.to_csv('all_HH_combined_mean.csv')

# %%
plt.figure(figsize=(10, 5))

plt.plot(mean_df['Gas m3_mean'])
plt.show()

# %%
# Calculate the Z-score for the 'Gas m3_mean' column
mean_df['Gas m3_mean_zscore'] = (mean_df['Gas m3_mean'] - mean_df['Gas m3_mean'].mean()) / mean_df['Gas m3_mean'].std()

# Define a threshold for the Z-score
threshold = 3

# Filter out the outliers
mean_df_no_outliers = mean_df[(mean_df['Gas m3_mean_zscore'] < threshold) & (mean_df['Gas m3_mean_zscore'] > -threshold)]

# Drop the Z-score column as it's no longer needed
mean_df_no_outliers = mean_df_no_outliers.drop(columns=['Gas m3_mean_zscore'])

# %%
mean_df_no_outliers
# Out:
#                   bath_temp_mean  backroom_hum_mean  mediumbed_temp_mean  \
# date
# 08/03/2020 00:00       19.214130                NaN               20.880
# 08/03/2020 00:30       18.975417               52.2               20.805
# 08/03/2020 01:00       18.696600               53.0               20.755
# 08/03/2020 01:30       18.514000               53.3               20.715
# 08/03/2020 02:00       18.628000               60.8               20.710
# ...                          ...                ...                  ...
# 31/03/2021 21:30       22.527391                NaN               24.170
# 31/03/2021 22:00       22.345000                NaN               24.020
# 31/03/2021 22:30       21.972727                NaN               23.910
# 31/03/2021 23:00       22.048261                NaN               23.760
# 31/03/2021 23:30       21.681364                NaN               23.590
#
#                   box_temp_mean  backroom_temp_mean  kit_hum_mean  \
# date
# 08/03/2020 00:00      22.503333                 NaN     57.991200
# 08/03/2020 00:30      22.290000               21.07     57.956923
# 08/03/2020 01:00      21.825000               20.46     58.089615
# 08/03/2020 01:30      21.623333               20.20     58.235769
# 08/03/2020 02:00      21.473333               19.99     58.053600
# ...                         ...                 ...           ...
# 31/03/2021 21:30      23.470000                 NaN     62.311739
# 31/03/2021 22:00      23.070000                 NaN     61.576087
# 31/03/2021 22:30      22.780000                 NaN     61.286522
# 31/03/2021 23:00      22.500000                 NaN     60.262381
# 31/03/2021 23:30      22.320000                 NaN     60.744545
#
#                   bed_temp_mean  toilet_hum_mean  mediumbed_hum_mean  \
# date
# 08/03/2020 00:00      20.074706             42.8               59.50
# 08/03/2020 00:30      20.157778             43.5               59.85
# 08/03/2020 01:00      19.740588             44.2               60.00
# 08/03/2020 01:30      20.026111             43.5               60.05
# 08/03/2020 02:00      19.987222             43.4               60.00
# ...                         ...              ...                 ...
# 31/03/2021 21:30      22.365000             68.4               57.00
# 31/03/2021 22:00      22.364167             65.8               57.30
# 31/03/2021 22:30      22.336667             63.4               58.20
# 31/03/2021 23:00      22.165833             61.7               58.30
# 31/03/2021 23:30      22.021667             60.2               58.60
#
#                   hall_temp_mean  ...  bed_hum_mean  util_hum_mean  \
# date                              ...
# 08/03/2020 00:00       20.404893  ...     56.405882           46.5
# 08/03/2020 00:30       20.038397  ...     56.150000           47.4
# 08/03/2020 01:00       20.087053  ...     57.241176           47.3
# 08/03/2020 01:30       19.573187  ...     56.594444           46.8
# 08/03/2020 02:00       19.528480  ...     56.827778           47.1
# ...                          ...  ...           ...            ...
# 31/03/2021 21:30       21.851053  ...     59.375000           55.2
# 31/03/2021 22:00       21.795000  ...     59.637500           56.0
# 31/03/2021 22:30       21.712632  ...     59.550000           55.8
# 31/03/2021 23:00       21.599474  ...     59.358333           55.8
# 31/03/2021 23:30       21.435263  ...     59.016667           55.7
#
#                   smallbed_hum_mean  dining_temp_mean  bath_hum_mean  \
# date
# 08/03/2020 00:00              62.15             22.30      53.743913
# 08/03/2020 00:30              61.60             20.52      55.335417
# 08/03/2020 01:00              61.30             20.08      55.742800
# 08/03/2020 01:30              61.40             19.68      55.981600
# 08/03/2020 02:00              61.25             21.17      57.528000
# ...                             ...               ...            ...
# 31/03/2021 21:30              55.15               NaN      63.204783
# 31/03/2021 22:00              55.15               NaN      64.783636
# 31/03/2021 22:30              54.95               NaN      62.839545
# 31/03/2021 23:00              54.95               NaN      61.382174
# 31/03/2021 23:30              54.55               NaN      61.550000
#
#                   box_hum_mean  rearbed_hum_mean  frontbed_hum_mean  \
# date
# 08/03/2020 00:00     49.166667              53.1          51.466667
# 08/03/2020 00:30     49.200000              52.7          51.166000
# 08/03/2020 01:00     50.750000              53.0          51.676667
# 08/03/2020 01:30     50.133333              53.3          51.573333
# 08/03/2020 02:00     50.866667              53.7          50.058000
# ...                        ...               ...                ...
# 31/03/2021 21:30     58.700000              59.7          61.180000
# 31/03/2021 22:00     59.400000              59.7          60.860000
# 31/03/2021 22:30     60.800000              59.7          60.120000
# 31/03/2021 23:00     61.600000              59.8          59.080000
# 31/03/2021 23:30     60.800000              59.8          58.960000
#
#                   leftbed_temp_mean  backbed_temp_mean
# date
# 08/03/2020 00:00          20.006667          21.472000
# 08/03/2020 00:30          19.856667          21.258000
# 08/03/2020 01:00          19.723333          21.038000
# 08/03/2020 01:30          19.603333          20.780000
# 08/03/2020 02:00          19.483333          20.712000
# ...                             ...                ...
# 31/03/2021 21:30          22.440000          24.423333
# 31/03/2021 22:00          22.610000          24.340000
# 31/03/2021 22:30          22.666667          24.146667
# 31/03/2021 23:00          22.503333          23.920000
# 31/03/2021 23:30          22.313333          23.833333
#
# [17893 rows x 44 columns]

# %%
# Plot the cleaned data
plt.plot( mean_df_no_outliers['Gas m3_mean'].tail(700))
plt.show()

# %%
mean_df_no_outliers.to_csv('all_HH_combined_mean.csv')

# %%
# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = mean_df['Gas m3_mean'].quantile(0.001)
Q3 = mean_df['Gas m3_mean'].quantile(0.99)

# Calculate the Interquartile Range (IQR)
IQR = Q3 - Q1

# Define the lower and upper bound for detecting outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter out the outliers
mean_df_no_outliers = mean_df[(mean_df['Gas m3_mean'] >= lower_bound) & (mean_df['Gas m3_mean'] <= upper_bound)]

# %%
# Plot the cleaned data
plt.plot( mean_df_no_outliers['Gas m3_mean'].head(700))
plt.show()

# %%
memory_usage = mean_df_no_outliers.memory_usage(deep=True)
total_memory = memory_usage.sum()

print("Memory usage by column (in bytes):")
print(memory_usage)
print(f"Total memory usage: {total_memory / (1024 ** 2):.2f} MB")
# Out:
# Memory usage by column (in bytes):
# Index                          1305897
# bath_temp_mean                  143112
# backroom_hum_mean               143112
# mediumbed_temp_mean             143112
# box_temp_mean                   143112
# backroom_temp_mean              143112
# kit_hum_mean                    143112
# bed_temp_mean                   143112
# toilet_hum_mean                 143112
# mediumbed_hum_mean              143112
# hall_temp_mean                  143112
# util_temp_mean                  143112
# kit_temp_mean                   143112
# rearbed_temp_mean               143112
# rightbed_hum_mean               143112
# liv_temp_mean                   143112
# rightbed_temp_mean              143112
# hall_hum_mean                   143112
# toilet_temp_mean                143112
# Gas m3_mean                     143112
# backbed_hum_mean                143112
# masterbed_hum_mean              143112
# Air temp (degC)_mean            143112
# RH (%)_mean                     143112
# liv_hum_mean                    143112
# frontbedabovedoor_hum_mean      143112
# Elec kWh_mean                   143112
# frontbedabovedoor_temp_mean     143112
# dining_hum_mean                 143112
# leftbed_hum_mean                143112
# smallliv_hum_mean               143112
# masterbed_temp_mean             143112
# smallbed_temp_mean              143112
# frontbed_temp_mean              143112
# smallliv_temp_mean              143112
# bed_hum_mean                    143112
# util_hum_mean                   143112
# smallbed_hum_mean               143112
# dining_temp_mean                143112
# bath_hum_mean                   143112
# box_hum_mean                    143112
# rearbed_hum_mean                143112
# frontbed_hum_mean               143112
# leftbed_temp_mean               143112
# backbed_temp_mean               143112
# Gas m3_mean_zscore              143112
# dtype: int64
# Total memory usage: 7.39 MB

# %%
mean_df_no_outliers.to_csv('all_HH_combined_mean.csv')
